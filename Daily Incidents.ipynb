# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.listdir('.')
# Out:
# ['Reported_Crash_Locations.csv',
#  'Raleigh_Police_Incidents_(NIBRS).csv',
#  '.DS_Store',
#  'Persons_Involved_in_Crashes.csv',
#  'Reported_Crash_Locations.zip',
#  'data.rds',
#  'Daily_Raleigh_Police_Incidents.csv',
#  'wake-county-restaurants',
#  'README.md',
#  'Bars and Restaurants.ipynb',
#  'Reported_Crash_Locations',
#  '.gitignore',
#  'Daily Incidents.ipynb',
#  'NCSUDatathon.Rproj',
#  'wake-county-restaurants.csv',
#  '.ipynb_checkpoints',
#  '.git',
#  'DataClean.Rmd',
#  'plots']

# %%
incidents = pd.read_csv('Raleigh_Police_Incidents_(NIBRS).csv')

# %%
incidents.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'GlobalID', 'case_number', 'crime_category',
#        'crime_code', 'crime_description', 'crime_type',
#        'reported_block_address', 'city_of_incident', 'city', 'district',
#        'reported_date', 'reported_year', 'reported_month', 'reported_day',
#        'reported_hour', 'reported_dayofwk', 'latitude', 'longitude', 'agency',
#        'updated_date'],
#       dtype='object')

# %%
incidents['crime_category'].value_counts()
# Out:
# MISCELLANEOUS                     77191
# ASSAULT                           41441
# LARCENY                           34961
# DRUGS                             25555
# VANDALISM                         21959
# LARCENY FROM MV                   21258
# FRAUD                             20999
# ALL OTHER OFFENSES                15892
# DRUG VIOLATIONS                   12358
# BURGLARY/RESIDENTIAL              10255
# TRAFFIC                            9890
# WEAPONS VIOLATION                  8298
# HUMANE                             8135
# MV THEFT                           6270
# SEX OFFENSES                       4150
# ROBBERY                            4110
# DISORDERLY CONDUCT                 3122
# BURGLARY/COMMERCIAL                2921
# STOLEN PROPERTY                    2298
# UNAUTHORIZED MOTOR VEHICLE USE     1612
# JUVENILE                           1268
# EMBEZZLEMENT                       1025
# LIQUOR LAW VIOLATIONS              1013
# ...

# %%
incidents[incidents['crime_category'] == 'ROBBERY']
# Out:
#                 X          Y  OBJECTID                              GlobalID  \
# 37788  -78.533460  35.737569     57648  c8447290-1781-45fb-a5b4-f123c3fd76c7
# 37825  -78.609232  35.749895     57727  a56d60a7-747e-4d34-ae41-33ab14073d78
# 37844  -78.555782  35.905834     57785  c43ef836-ff48-4d6b-a448-0bceb0193d51
# 37977         NaN        NaN     58080  df755807-09ec-4084-9d39-222fa85b150f
# 38076  -78.573250  35.850473     58284  c9f42ed0-b5b7-4c94-9563-4926a2a2f40d
# ...           ...        ...       ...                                   ...
# 337269 -78.595100  35.840878    618583  3e942bbb-2949-4dc5-a78a-ec6e786d3d45
# 337281 -78.587372  35.788546    618595  2cd9c86b-36c0-4b80-8d87-1a8c0865230a
# 337302 -78.587372  35.788546    618616  1c1a7718-682f-4951-ba28-2a7f37cb07ec
# 337503 -78.599965  35.811046    618818  b14a1ae8-53c5-4d66-bd84-8d2671bb57ad
# 337703 -78.663946  35.800457    619018  e536437f-03ac-4b01-ade6-9ecf7ed70752
#
# ...

# %%
# !pip install sns
# Out:
# ...
#   Created wheel for sns: filename=sns-0.1-py3-none-any.whl size=2661 sha256=152ae60433da71eb0a51187a194d71060e27ab50e8888db67f13388ae992da9e
#   Stored in directory: /Users/bhrijpatel/Library/Caches/pip/wheels/94/30/68/c7bbc5257894097a14adf5c7d6e7de56127c9936f27afe2416
# Successfully built sns
# ...

# %%
import seaborn as sns

# %%
ax = sns.countplot(x="crime_category", data=incidents, col = 'district')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-30fab5b28516> in <module>
# ----> 1 ax = sns.countplot(x="crime_category", data=incidents, col = 'district')
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3557         ax = plt.gca()
#    3558
# -> 3559     plotter.plot(ax, kwargs)
#    3560     return ax
#    3561
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1655     def plot(self, ax, bar_kws):
#    1656         """Make the plot."""
# -> 1657         self.draw_bars(ax, bar_kws)
#    1658         self.annotate_axes(ax)
#    1659         if self.orient == "h":
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in draw_bars(self, ax, kws)
#    1620
# ...

# %%
# Out:
# '0.10.1'
